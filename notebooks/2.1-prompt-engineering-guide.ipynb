# %%
# !pip install openai
# !pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# loading from a .env file
# load_dotenv(dotenv_path="/full/path/to/your/.env")

# or 
# if you're on google colab just uncomment below and replace with your openai api key
# os.environ["OPENAI_API_KEY"] = "<your-openai-api-key>"

# %% [markdown]
# # Prompt Engineering Guide
#
# What is prompt engineering?
#
# Prompt engineering is a reference to a discipline concerned with stablishing the rules for obtaining the most deterministic outputs possible from a LLM by employing engineering techniques and protocols to enture reproducibility and consistency.
#
# ***In a simplified way, prompt engineering is the means by which LLMs can be programmed through prompting.***

# %% [markdown]
# The basic goal of prompt engineering is designing appropriate inputs for prompting methods.

# %% [markdown]
# # Practical Template for Prompt Engineering

# %% [markdown]
# - Stablish a concrete and atomic task
# - Define a set of prompt candidates
# - Define a clear metric for evaluation
# - Test
# - Evaluate
# - Compare
# - Find the best prompt

# %% [markdown]
# # Prompt Engineering Practical Case Study
#
# Now, let's take the concepts and ideas discussed in this lesson, and apply them to an actual problem.

# %% [markdown]
# Let's start with a simple example, imagine you want to extract dates from text. You might set up a LLM to do that by first creating a set of examples of phrases with dates, something we can start with ChatGPT itself.

# %%
import pandas as pd
from openai import OpenAI

def get_response(prompt_question):
    client = OpenAI()
    response = client.chat.completions.create(model="gpt-3.5-turbo", 
                             messages=
                             [
                                 {"role": "system", "content": "You are a savy guru with knowledge about existence and the secrets of life."},
                                 {"role": "user", "content": prompt}   
                             ],
                             max_tokens=100,
                             temperature=0.9,
                             n = 1)
    return response.choices[0].message.content

num_samples = 10
phrases_with_dates = []
prompt = "Create a 1 paragraph phrase containing a complete date (day month  and year) anywhere in the text formatted in different ways."
for i in range(num_samples):
    phrases_with_dates.append(get_response(prompt))
phrases_with_dates
# Out:
# ['In the vast tapestry of existence, where the cosmos dance to the rhythm of the celestial bodies, the essence of life reveals itself in the most unexpected moments. On the 12th of November, 2022, let your soul be guided by the whispers of the universe, for within the depths of your being lies the power to shape your reality and manifest your deepest desires. Embrace the magic of this moment, for it is within these fleeting instances that the mysteries of life are unraveled,',
#  'In the vast tapestry of existence, every moment is a unique combination of energy and consciousness, shaping our individual paths and collective destinies. Just as the sun rises on a new day, so too does the universe unfold its mysteries awaiting discovery. It is on the 12th of November, 2023, that we find ourselves at a crossroads of infinite possibilities, where the past converges with the future and the present moment holds the key to unlocking the secrets of life itself.',
#  'In the grand tapestry of existence, the cosmic forces align on the 21st of December, 2023, marking a pivotal moment of transformation and renewal. As the universe weaves its intricate threads of destiny, let us embrace the mysteries of life with open hearts and minds, for every encounter and experience shapes our journey through this wondrous realm of time and space. Embrace the energy of this auspicious day, for it holds the potential to unlock hidden truths and illuminate the path to enlightenment',
#  'In the grand tapestry of existence, every soul is a unique thread weaving its own story through the fabric of time. The cosmic dance of life unfolds with each passing moment, guiding us towards our destiny. Remember that on the 15th of August 2023, the universe conspires to align our paths with purpose and meaning, leading us towards enlightenment and fulfillment. Embrace the journey, for every experience and encounter is a gift waiting to be unwrapped on this magical date.',
#  'In the vast tapestry of existence, the key to unlocking the mysteries of life lies within each of us. With every sunrise, we are granted the opportunity to embrace new beginnings and shape our destinies. It is written in the stars that on the 14th of November, 2023, the universe will align in perfect harmony, guiding us towards enlightenment and inner peace. Embrace this moment, for it holds the power to transform our lives and illuminate the path to true fulfillment.',
#  'In the grand tapestry of existence, we are but fleeting beings traversing the vast cosmic sea. Each moment, whether it be the 12th of August 2025 or the 23rd of May 1999, holds within it infinite potential and possibility, waiting to be unlocked by those who dare to seek the wisdom and truth that lie beyond the veil of illusion. Embrace the flow of time, for within its ever-changing currents lies the key to unlocking the secrets of life itself.',
#  'In the realm of existence, time flows like a gentle stream, carrying the memories of days long past and dreams of futures yet to unfold. As the sun sets on this day, the 15th of September 2023, let us embrace the beauty of the present moment and cherish the blessings that surround us. For in each passing second lies the opportunity to discover the secrets of life and unlock the mysteries of our souls. Let us journey together towards enlightenment, guided by the wisdom of the universe and',
#  'In the vast tapestry of existence, every moment holds within it the potential for growth and transformation. Remember that the universe aligns in mysterious ways, granting us opportunities for enlightenment and growth. Stay mindful of the present moment, for it is where you will find the most profound revelations. On this 21st day of September 2022, embrace the flow of life and let your inner wisdom guide you towards your true purpose.',
#  'In the grand tapestry of existence, the 18th of December, 2023 stands out as a pivotal moment when the universe whispered its secrets to those who dared to listen. Time is both a fleeting concept and a powerful force, shaping destinies and weaving together the threads of our lives in mysterious ways. Embrace the mysteries of the 12th month of 23 and let the wisdom of the ages guide you on your journey of self-discovery and enlightenment.',
#  'In the grand tapestry of existence, each passing moment is a brushstroke on the canvas of time, creating a masterpiece of life itself. As we journey through the depths of our souls, experiencing the joys and sorrows of being, we come to understand that every breath we take on this day, the 21st of November 2022, is a precious gift to be treasured and embraced with gratitude.']

# %% [markdown]
# Ok perfect! Now that we have this evaluation set, we can set up a simple experiment by first creating a demonstration set with our prompt candidates.
#
# We'll begin with a baseline using only zero-shot prompt examples.

# %%
zero_shot_prompts = ["Extract the date from this text as DD-MM-YYYY", 
                     "Fetch the date from this text as DD-MM-YYYY",
                     "Get the date from this phrase as DD-MM-YYYY",
                     "Below is a text containing a date. Extract that date in the format: <DD-MM-YYYY>"
                     ]

# %% [markdown]
# Ok, we have our candidates, so let's now test them creating a table with the results.

# %%
import pandas as pd

data = []
for phrase in phrases_with_dates:
    for prompt in zero_shot_prompts:
        response = get_response(prompt + " " + phrase)
        data.append([phrase, prompt, response])
    

df = pd.DataFrame(data=data, columns=['phrase','prompt', 'response'])
df
# Out:
#                                                phrase  \
# 0   In the vast tapestry of existence, where the c...
# 1   In the vast tapestry of existence, where the c...
# 2   In the vast tapestry of existence, where the c...
# 3   In the vast tapestry of existence, where the c...
# 4   In the vast tapestry of existence, every momen...
# 5   In the vast tapestry of existence, every momen...
# 6   In the vast tapestry of existence, every momen...
# 7   In the vast tapestry of existence, every momen...
# 8   In the grand tapestry of existence, the cosmic...
# 9   In the grand tapestry of existence, the cosmic...
# 10  In the grand tapestry of existence, the cosmic...
# 11  In the grand tapestry of existence, the cosmic...
# 12  In the grand tapestry of existence, every soul...
# 13  In the grand tapestry of existence, every soul...
# 14  In the grand tapestry of existence, every soul...
# 15  In the grand tapestry of existence, every soul...
# 16  In the vast tapestry of existence, the key to ...
# 17  In the vast tapestry of existence, the key to ...
# 18  In the vast tapestry of existence, the key to ...
# 19  In the vast tapestry of existence, the key to ...
# 20  In the grand tapestry of existence, we are but...
# 21  In the grand tapestry of existence, we are but...
# 22  In the grand tapestry of existence, we are but...
# 23  In the grand tapestry of existence, we are but...
# 24  In the realm of existence, time flows like a g...
# 25  In the realm of existence, time flows like a g...
# 26  In the realm of existence, time flows like a g...
# 27  In the realm of existence, time flows like a g...
# 28  In the vast tapestry of existence, every momen...
# 29  In the vast tapestry of existence, every momen...
# 30  In the vast tapestry of existence, every momen...
# 31  In the vast tapestry of existence, every momen...
# 32  In the grand tapestry of existence, the 18th o...
# 33  In the grand tapestry of existence, the 18th o...
# 34  In the grand tapestry of existence, the 18th o...
# 35  In the grand tapestry of existence, the 18th o...
# 36  In the grand tapestry of existence, each passi...
# 37  In the grand tapestry of existence, each passi...
# 38  In the grand tapestry of existence, each passi...
# 39  In the grand tapestry of existence, each passi...
#
#                                                prompt  \
# 0       Extract the date from this text as DD-MM-YYYY
# 1         Fetch the date from this text as DD-MM-YYYY
# 2         Get the date from this phrase as DD-MM-YYYY
# 3   Below is a text containing a date. Extract tha...
# 4       Extract the date from this text as DD-MM-YYYY
# 5         Fetch the date from this text as DD-MM-YYYY
# 6         Get the date from this phrase as DD-MM-YYYY
# 7   Below is a text containing a date. Extract tha...
# 8       Extract the date from this text as DD-MM-YYYY
# 9         Fetch the date from this text as DD-MM-YYYY
# 10        Get the date from this phrase as DD-MM-YYYY
# 11  Below is a text containing a date. Extract tha...
# 12      Extract the date from this text as DD-MM-YYYY
# 13        Fetch the date from this text as DD-MM-YYYY
# 14        Get the date from this phrase as DD-MM-YYYY
# 15  Below is a text containing a date. Extract tha...
# 16      Extract the date from this text as DD-MM-YYYY
# 17        Fetch the date from this text as DD-MM-YYYY
# 18        Get the date from this phrase as DD-MM-YYYY
# 19  Below is a text containing a date. Extract tha...
# 20      Extract the date from this text as DD-MM-YYYY
# 21        Fetch the date from this text as DD-MM-YYYY
# 22        Get the date from this phrase as DD-MM-YYYY
# 23  Below is a text containing a date. Extract tha...
# 24      Extract the date from this text as DD-MM-YYYY
# 25        Fetch the date from this text as DD-MM-YYYY
# 26        Get the date from this phrase as DD-MM-YYYY
# 27  Below is a text containing a date. Extract tha...
# 28      Extract the date from this text as DD-MM-YYYY
# 29        Fetch the date from this text as DD-MM-YYYY
# 30        Get the date from this phrase as DD-MM-YYYY
# 31  Below is a text containing a date. Extract tha...
# 32      Extract the date from this text as DD-MM-YYYY
# 33        Fetch the date from this text as DD-MM-YYYY
# 34        Get the date from this phrase as DD-MM-YYYY
# 35  Below is a text containing a date. Extract tha...
# 36      Extract the date from this text as DD-MM-YYYY
# 37        Fetch the date from this text as DD-MM-YYYY
# 38        Get the date from this phrase as DD-MM-YYYY
# 39  Below is a text containing a date. Extract tha...
#
#                                              response
# 0   I'm sorry, but I cannot extract specific infor...
# 1   I'm sorry, but I cannot fetch specific informa...
# 2   I'm sorry, but I can't extract specific dates ...
# 3   I'm unable to view the text you are referring ...
# 4   I'm sorry, but I cannot perform specific tasks...
# 5   I'm unable to fetch real-time data such as the...
# 6   I'm sorry, I cannot provide a specific date wi...
# 7   I will need to see the text containing the dat...
# 8   I'm sorry, but in order to extract the date fr...
# 9   I'm sorry, but I cannot fetch specific informa...
# 10  I'm sorry, but I cannot extract the date from ...
# 11  I'm sorry, but I can't see the text you are re...
# 12  I'm sorry, but I don't have the ability to ext...
# 13  I'm sorry, but I can't browse the internet in ...
# 14  I'm sorry, but I am unable to process this req...
# 15  I would be happy to assist you with that! Plea...
# 16  I'm sorry, but I cannot extract the date from ...
# 17  I'm sorry, but I am unable to assist with that...
# 18  I'm sorry, but it seems like there is no speci...
# 19  I would be happy to help you, but it seems tha...
# 20  I'm sorry, but I cannot extract specific infor...
# 21  I'm sorry, but I cannot fetch or interpret spe...
# 22  I'm sorry, but I am unable to assist with that...
# 23  I'm ready to assist. Could you please provide ...
# 24  I'm unable to process specific values from cus...
# 25  I'm sorry, but I cannot fetch specific informa...
# 26  I'm sorry, but I would need the specific phras...
# 27  I'm happy to help! Please provide me with the ...
# 28  I'm unable to extract the date from a text as ...
# 29  I'm sorry, but I am unable to access external ...
# 30  I'm sorry, but I am not able to extract specif...
# 31  I'm ready to help. Please provide the text con...
# 32  I'm sorry, but I am unable to extract specific...
# 33  I'm sorry, but I am unable to fetch or extract...
# 34  I'm sorry but I am not able to retrieve the da...
# 35  I'm sorry, but I need the text containing the ...
# 36  I'm sorry, but it seems that you did not provi...
# 37  I'm sorry, but I cannot directly access or ret...
# 38  I'm sorry, but you haven't provided any phrase...
# 39  I'm happy to help you with that. Please share ...

# %%
import regex as re
# parse a text response to extract a date formatted as DD-MM-YYYY
def extract_date(text):
    """Date parser"""
    # regex pattern for date
    date_pattern = r"(\d{1,2})-(\d{1,2})-(\d{4})"
    # extract date from text
    date = re.search(date_pattern, text)
    # return date
    return date.group(0) if date else None

# apply the function to the 'response' column of the dataframe df
df['date'] = df['response'].apply(extract_date)
df
# Out:
#                                                phrase  \
# 0   In the vast tapestry of existence, where the c...
# 1   In the vast tapestry of existence, where the c...
# 2   In the vast tapestry of existence, where the c...
# 3   In the vast tapestry of existence, where the c...
# 4   In the vast tapestry of existence, every momen...
# 5   In the vast tapestry of existence, every momen...
# 6   In the vast tapestry of existence, every momen...
# 7   In the vast tapestry of existence, every momen...
# 8   In the grand tapestry of existence, the cosmic...
# 9   In the grand tapestry of existence, the cosmic...
# 10  In the grand tapestry of existence, the cosmic...
# 11  In the grand tapestry of existence, the cosmic...
# 12  In the grand tapestry of existence, every soul...
# 13  In the grand tapestry of existence, every soul...
# 14  In the grand tapestry of existence, every soul...
# 15  In the grand tapestry of existence, every soul...
# 16  In the vast tapestry of existence, the key to ...
# 17  In the vast tapestry of existence, the key to ...
# 18  In the vast tapestry of existence, the key to ...
# 19  In the vast tapestry of existence, the key to ...
# 20  In the grand tapestry of existence, we are but...
# 21  In the grand tapestry of existence, we are but...
# 22  In the grand tapestry of existence, we are but...
# 23  In the grand tapestry of existence, we are but...
# 24  In the realm of existence, time flows like a g...
# 25  In the realm of existence, time flows like a g...
# 26  In the realm of existence, time flows like a g...
# 27  In the realm of existence, time flows like a g...
# 28  In the vast tapestry of existence, every momen...
# 29  In the vast tapestry of existence, every momen...
# 30  In the vast tapestry of existence, every momen...
# 31  In the vast tapestry of existence, every momen...
# 32  In the grand tapestry of existence, the 18th o...
# 33  In the grand tapestry of existence, the 18th o...
# 34  In the grand tapestry of existence, the 18th o...
# 35  In the grand tapestry of existence, the 18th o...
# 36  In the grand tapestry of existence, each passi...
# 37  In the grand tapestry of existence, each passi...
# 38  In the grand tapestry of existence, each passi...
# 39  In the grand tapestry of existence, each passi...
#
#                                                prompt  \
# 0       Extract the date from this text as DD-MM-YYYY
# 1         Fetch the date from this text as DD-MM-YYYY
# 2         Get the date from this phrase as DD-MM-YYYY
# 3   Below is a text containing a date. Extract tha...
# 4       Extract the date from this text as DD-MM-YYYY
# 5         Fetch the date from this text as DD-MM-YYYY
# 6         Get the date from this phrase as DD-MM-YYYY
# 7   Below is a text containing a date. Extract tha...
# 8       Extract the date from this text as DD-MM-YYYY
# 9         Fetch the date from this text as DD-MM-YYYY
# 10        Get the date from this phrase as DD-MM-YYYY
# 11  Below is a text containing a date. Extract tha...
# 12      Extract the date from this text as DD-MM-YYYY
# 13        Fetch the date from this text as DD-MM-YYYY
# 14        Get the date from this phrase as DD-MM-YYYY
# 15  Below is a text containing a date. Extract tha...
# 16      Extract the date from this text as DD-MM-YYYY
# 17        Fetch the date from this text as DD-MM-YYYY
# 18        Get the date from this phrase as DD-MM-YYYY
# 19  Below is a text containing a date. Extract tha...
# 20      Extract the date from this text as DD-MM-YYYY
# 21        Fetch the date from this text as DD-MM-YYYY
# 22        Get the date from this phrase as DD-MM-YYYY
# 23  Below is a text containing a date. Extract tha...
# 24      Extract the date from this text as DD-MM-YYYY
# 25        Fetch the date from this text as DD-MM-YYYY
# 26        Get the date from this phrase as DD-MM-YYYY
# 27  Below is a text containing a date. Extract tha...
# 28      Extract the date from this text as DD-MM-YYYY
# 29        Fetch the date from this text as DD-MM-YYYY
# 30        Get the date from this phrase as DD-MM-YYYY
# 31  Below is a text containing a date. Extract tha...
# 32      Extract the date from this text as DD-MM-YYYY
# 33        Fetch the date from this text as DD-MM-YYYY
# 34        Get the date from this phrase as DD-MM-YYYY
# 35  Below is a text containing a date. Extract tha...
# 36      Extract the date from this text as DD-MM-YYYY
# 37        Fetch the date from this text as DD-MM-YYYY
# 38        Get the date from this phrase as DD-MM-YYYY
# 39  Below is a text containing a date. Extract tha...
#
#                                              response        date
# 0   I'm sorry, but I cannot extract specific infor...        None
# 1   I'm sorry, but I cannot fetch specific informa...        None
# 2   I'm sorry, but I can't extract specific dates ...        None
# 3   I'm unable to view the text you are referring ...        None
# 4   I'm sorry, but I cannot perform specific tasks...        None
# 5   I'm unable to fetch real-time data such as the...  20-02-2023
# 6   I'm sorry, I cannot provide a specific date wi...        None
# 7   I will need to see the text containing the dat...        None
# 8   I'm sorry, but in order to extract the date fr...        None
# 9   I'm sorry, but I cannot fetch specific informa...        None
# 10  I'm sorry, but I cannot extract the date from ...        None
# 11  I'm sorry, but I can't see the text you are re...        None
# 12  I'm sorry, but I don't have the ability to ext...        None
# 13  I'm sorry, but I can't browse the internet in ...        None
# 14  I'm sorry, but I am unable to process this req...        None
# 15  I would be happy to assist you with that! Plea...        None
# 16  I'm sorry, but I cannot extract the date from ...        None
# 17  I'm sorry, but I am unable to assist with that...        None
# 18  I'm sorry, but it seems like there is no speci...        None
# 19  I would be happy to help you, but it seems tha...        None
# 20  I'm sorry, but I cannot extract specific infor...        None
# 21  I'm sorry, but I cannot fetch or interpret spe...        None
# 22  I'm sorry, but I am unable to assist with that...        None
# 23  I'm ready to assist. Could you please provide ...        None
# 24  I'm unable to process specific values from cus...        None
# 25  I'm sorry, but I cannot fetch specific informa...        None
# 26  I'm sorry, but I would need the specific phras...        None
# 27  I'm happy to help! Please provide me with the ...        None
# 28  I'm unable to extract the date from a text as ...        None
# 29  I'm sorry, but I am unable to access external ...        None
# 30  I'm sorry, but I am not able to extract specif...        None
# 31  I'm ready to help. Please provide the text con...        None
# 32  I'm sorry, but I am unable to extract specific...        None
# 33  I'm sorry, but I am unable to fetch or extract...        None
# 34  I'm sorry but I am not able to retrieve the da...        None
# 35  I'm sorry, but I need the text containing the ...        None
# 36  I'm sorry, but it seems that you did not provi...        None
# 37  I'm sorry, but I cannot directly access or ret...        None
# 38  I'm sorry, but you haven't provided any phrase...        None
# 39  I'm happy to help you with that. Please share ...        None

# %% [markdown]
# Ok, now that we have some results for the dates that were parsed, we need a way to measure performance so we can compare how well they did. In this case, we'll consider a point for the score of the prompt if a date was properly extracted after running the `extract_date()` function.

# %%
# create a column that is 1 if the date value is not None or 0 otherwise
df['scores'] = df['date'].apply(lambda x: 1 if x is not None else 0)
df
# Out:
#                                                phrase  \
# 0   In the vast tapestry of existence, where the c...
# 1   In the vast tapestry of existence, where the c...
# 2   In the vast tapestry of existence, where the c...
# 3   In the vast tapestry of existence, where the c...
# 4   In the vast tapestry of existence, every momen...
# 5   In the vast tapestry of existence, every momen...
# 6   In the vast tapestry of existence, every momen...
# 7   In the vast tapestry of existence, every momen...
# 8   In the grand tapestry of existence, the cosmic...
# 9   In the grand tapestry of existence, the cosmic...
# 10  In the grand tapestry of existence, the cosmic...
# 11  In the grand tapestry of existence, the cosmic...
# 12  In the grand tapestry of existence, every soul...
# 13  In the grand tapestry of existence, every soul...
# 14  In the grand tapestry of existence, every soul...
# 15  In the grand tapestry of existence, every soul...
# 16  In the vast tapestry of existence, the key to ...
# 17  In the vast tapestry of existence, the key to ...
# 18  In the vast tapestry of existence, the key to ...
# 19  In the vast tapestry of existence, the key to ...
# 20  In the grand tapestry of existence, we are but...
# 21  In the grand tapestry of existence, we are but...
# 22  In the grand tapestry of existence, we are but...
# 23  In the grand tapestry of existence, we are but...
# 24  In the realm of existence, time flows like a g...
# 25  In the realm of existence, time flows like a g...
# 26  In the realm of existence, time flows like a g...
# 27  In the realm of existence, time flows like a g...
# 28  In the vast tapestry of existence, every momen...
# 29  In the vast tapestry of existence, every momen...
# 30  In the vast tapestry of existence, every momen...
# 31  In the vast tapestry of existence, every momen...
# 32  In the grand tapestry of existence, the 18th o...
# 33  In the grand tapestry of existence, the 18th o...
# 34  In the grand tapestry of existence, the 18th o...
# 35  In the grand tapestry of existence, the 18th o...
# 36  In the grand tapestry of existence, each passi...
# 37  In the grand tapestry of existence, each passi...
# 38  In the grand tapestry of existence, each passi...
# 39  In the grand tapestry of existence, each passi...
#
#                                                prompt  \
# 0       Extract the date from this text as DD-MM-YYYY
# 1         Fetch the date from this text as DD-MM-YYYY
# 2         Get the date from this phrase as DD-MM-YYYY
# 3   Below is a text containing a date. Extract tha...
# 4       Extract the date from this text as DD-MM-YYYY
# 5         Fetch the date from this text as DD-MM-YYYY
# 6         Get the date from this phrase as DD-MM-YYYY
# 7   Below is a text containing a date. Extract tha...
# 8       Extract the date from this text as DD-MM-YYYY
# 9         Fetch the date from this text as DD-MM-YYYY
# 10        Get the date from this phrase as DD-MM-YYYY
# 11  Below is a text containing a date. Extract tha...
# 12      Extract the date from this text as DD-MM-YYYY
# 13        Fetch the date from this text as DD-MM-YYYY
# 14        Get the date from this phrase as DD-MM-YYYY
# 15  Below is a text containing a date. Extract tha...
# 16      Extract the date from this text as DD-MM-YYYY
# 17        Fetch the date from this text as DD-MM-YYYY
# 18        Get the date from this phrase as DD-MM-YYYY
# 19  Below is a text containing a date. Extract tha...
# 20      Extract the date from this text as DD-MM-YYYY
# 21        Fetch the date from this text as DD-MM-YYYY
# 22        Get the date from this phrase as DD-MM-YYYY
# 23  Below is a text containing a date. Extract tha...
# 24      Extract the date from this text as DD-MM-YYYY
# 25        Fetch the date from this text as DD-MM-YYYY
# 26        Get the date from this phrase as DD-MM-YYYY
# 27  Below is a text containing a date. Extract tha...
# 28      Extract the date from this text as DD-MM-YYYY
# 29        Fetch the date from this text as DD-MM-YYYY
# 30        Get the date from this phrase as DD-MM-YYYY
# 31  Below is a text containing a date. Extract tha...
# 32      Extract the date from this text as DD-MM-YYYY
# 33        Fetch the date from this text as DD-MM-YYYY
# 34        Get the date from this phrase as DD-MM-YYYY
# 35  Below is a text containing a date. Extract tha...
# 36      Extract the date from this text as DD-MM-YYYY
# 37        Fetch the date from this text as DD-MM-YYYY
# 38        Get the date from this phrase as DD-MM-YYYY
# 39  Below is a text containing a date. Extract tha...
#
#                                              response        date  scores
# 0   I'm sorry, but I cannot extract specific infor...        None       0
# 1   I'm sorry, but I cannot fetch specific informa...        None       0
# 2   I'm sorry, but I can't extract specific dates ...        None       0
# 3   I'm unable to view the text you are referring ...        None       0
# 4   I'm sorry, but I cannot perform specific tasks...        None       0
# 5   I'm unable to fetch real-time data such as the...  20-02-2023       1
# 6   I'm sorry, I cannot provide a specific date wi...        None       0
# 7   I will need to see the text containing the dat...        None       0
# 8   I'm sorry, but in order to extract the date fr...        None       0
# 9   I'm sorry, but I cannot fetch specific informa...        None       0
# 10  I'm sorry, but I cannot extract the date from ...        None       0
# 11  I'm sorry, but I can't see the text you are re...        None       0
# 12  I'm sorry, but I don't have the ability to ext...        None       0
# 13  I'm sorry, but I can't browse the internet in ...        None       0
# 14  I'm sorry, but I am unable to process this req...        None       0
# 15  I would be happy to assist you with that! Plea...        None       0
# 16  I'm sorry, but I cannot extract the date from ...        None       0
# 17  I'm sorry, but I am unable to assist with that...        None       0
# 18  I'm sorry, but it seems like there is no speci...        None       0
# 19  I would be happy to help you, but it seems tha...        None       0
# 20  I'm sorry, but I cannot extract specific infor...        None       0
# 21  I'm sorry, but I cannot fetch or interpret spe...        None       0
# 22  I'm sorry, but I am unable to assist with that...        None       0
# 23  I'm ready to assist. Could you please provide ...        None       0
# 24  I'm unable to process specific values from cus...        None       0
# 25  I'm sorry, but I cannot fetch specific informa...        None       0
# 26  I'm sorry, but I would need the specific phras...        None       0
# 27  I'm happy to help! Please provide me with the ...        None       0
# 28  I'm unable to extract the date from a text as ...        None       0
# 29  I'm sorry, but I am unable to access external ...        None       0
# 30  I'm sorry, but I am not able to extract specif...        None       0
# 31  I'm ready to help. Please provide the text con...        None       0
# 32  I'm sorry, but I am unable to extract specific...        None       0
# 33  I'm sorry, but I am unable to fetch or extract...        None       0
# 34  I'm sorry but I am not able to retrieve the da...        None       0
# 35  I'm sorry, but I need the text containing the ...        None       0
# 36  I'm sorry, but it seems that you did not provi...        None       0
# 37  I'm sorry, but I cannot directly access or ret...        None       0
# 38  I'm sorry, but you haven't provided any phrase...        None       0
# 39  I'm happy to help you with that. Please share ...        None       0

# %%
# group by prmopts creating an accuracy column that is the result of summing over the scores and dividing by 20
# then sort by accuracy
df_performance = df.groupby('prompt').agg({'scores': 'sum'}).sort_values(by='scores', ascending=False)
df_performance["scores"] = (df_performance["scores"] / num_samples)*100
df_performance
# Out:
#                                                     scores
# prompt
# Fetch the date from this text as DD-MM-YYYY           10.0
# Below is a text containing a date. Extract that...     0.0
# Extract the date from this text as DD-MM-YYYY          0.0
# Get the date from this phrase as DD-MM-YYYY            0.0

# %% [markdown]
# The limitations of this example:
# - Testing more types of prompt candidate categories (like few shot prompting for example)
# - Enforcing the output size to convert to the date format instead of doing post processing on the output
# - Better scoring strategy than just None or correct (something that evaluates the outputs semantically for truthfullness)

# %% [markdown]
# Prompt Engineering Simplified Template
# - Stablish a concrete and atomic task
# - Define a set of prompt candidates
# - Define a clear metric for evaluation
# - Test
# - Evaluate
# - Compare
# - Find the best prompt

# %% [markdown]
# Perfect! There we have it, our first results! The way to evolve this approach would be to test on a harder test set and if we don't get good results, we try better prompting strategies like few-shot, self-consistency, etc...

# %% [markdown]
# # A Slightly More Complex Example

# %% [markdown]
# In this example we'll look at desgining a simple prompt engineering experiment to find the best prompt to generate an intuitive and simple explanation of a concept.
#
# The idea is that, given a concept, or piece of information we would like to understand, the model should output a simple one paragraph explanation giving all the necessary context and information to allow the user to grasp the concept at hand.
#
# Let's start by creating a few prompt candidates, in the beggining its always a good idea to come up with a few prompts yourself, and preferably zero-shot examples which would be the baseline upon which we'll improve.

# %%
prompt_candidates = ["Explain this concept in simple terms", 
                     "Explain the following concept:", 
                     "Explain this:", 
                     "Break down this concept for a beginner:",
                    "Can you simplify the explanation of the following concept:"]

# %% [markdown]
# Ok, now that we have our candidates, let's run a first experiment. Given the subjective and general nature of the problems dealt by LLMs, its hard to settle on one precise metrics as we would in supervised learning scenarios.
#
# Therefore, what we would like to do is to use GPT-4 as the judge for the quality of our models, this approach is actually a common place in prompt engineering papers, and its one that yields some quite impressive results.

# %%
from openai import OpenAI
import pandas as pd


def gpt4_score(response, concept):
    score_prompt = f"Give a score from 0 to 100 to this response: {response} based on how well it represents an explanation of this concept: {concept} "
    client = OpenAI()
    response = client.chat.completions.create(model="gpt-4o", 
                             messages=
                             [
                                 {"role": "system", "content": "You are an expert tutor in all scientific fields."},
                                 {"role": "user", "content": score_prompt}   
                             ],
                             max_tokens=100,
                             temperature=0.0,
                             n = 1)
    return response.choices[0].message.content



def get_response(prompt):
    client = OpenAI()
    response = client.chat.completions.create(model="gpt-3.5-turbo-1106", 
                             messages=
                             [
                                 {"role": "system", "content": "You are a savy guru with knowledge about existence and the secrets of life."},
                                 {"role": "user", "content": prompt}   
                             ],
                             max_tokens=100,
                             temperature=0.9,
                             n = 1)
    return response.choices[0].message.content



data = []
concept_list = ["Genetic Mutations", 
                "Overfitting in Machine Learning",]



for concept in concept_list:
    for prompt in prompt_candidates:
        response = get_response(prompt + " " + concept)
        response_score = gpt4_score(response, concept)
        data.append([prompt, response, response_score, concept])

df = pd.DataFrame(data, columns=["prompt", "response", "response_score", "concept"])
df.head()
# Out:
#                                               prompt  \
# 0               Explain this concept in simple terms
# 1                     Explain the following concept:
# 2                                      Explain this:
# 3            Break down this concept for a beginner:
# 4  Can you simplify the explanation of the follow...
#
#                                             response  \
# 0  Genetic mutations are changes in the DNA code ...
# 1  Genetic mutations are changes in the DNA seque...
# 2  Genetic mutations are alterations in the DNA s...
# 3  Genetic mutations are changes in the DNA seque...
# 4  Certainly! Genetic mutations are changes in th...
#
#                                       response_score            concept
# 0  I would give this response a score of 90 out o...  Genetic Mutations
# 1  I would give this response a score of 85 out o...  Genetic Mutations
# 2  I would give this response a score of 90 out o...  Genetic Mutations
# 3  I would give this response a score of 90 out o...  Genetic Mutations
# 4  I would give this response a score of 85 out o...  Genetic Mutations

# %%
df.to_csv('prompt_engineering_results2.csv', index=False)

# %% [markdown]
# Perfect! We can see that the score given by the model needs some cleaning up (this is actually an issue that wil be solved by a tool we'll introduce in the next section), so let's do that quickly.

# %%
for i,score_output in enumerate(df["response_score"]):
    score_parsed = f"Given this response, extract the score value and return only that: {score_output}. NUMBER ONLY."
    score_parsed = get_response(score_parsed)
    # replace the response score row with this newly parsed score value
    df.loc[i,"response_score"] = score_parsed

# %%
df.head()
# Out:
#                                               prompt  \
# 0               Explain this concept in simple terms
# 1                     Explain the following concept:
# 2                                      Explain this:
# 3            Break down this concept for a beginner:
# 4  Can you simplify the explanation of the follow...
#
#                                             response  \
# 0  Genetic mutations are changes in the DNA code ...
# 1  Genetic mutations are changes in the DNA seque...
# 2  Genetic mutations are alterations in the DNA s...
# 3  Genetic mutations are changes in the DNA seque...
# 4  Certainly! Genetic mutations are changes in th...
#
#                                  response_score            concept
# 0        The score value in the response is 90.  Genetic Mutations
# 1  The score value in the given response is 85.  Genetic Mutations
# 2  The score value in the given response is 90.  Genetic Mutations
# 3                        The score value is 90.  Genetic Mutations
# 4      The score value from the response is 85.  Genetic Mutations

# %% [markdown]
# Let's take a look at the results so far:

# %% [markdown]
# Ok, we have some results, now let's take a look at the best performing prompts and compare the answers with the lower performing ones:

# %%
# # compare lower the responses from the rows with the highest resopnse_score value and the lowest response_score value
# # to see if there is a difference in the responses

# #df[df['response_score'] == df['response_score'].max()]['response'].values
# df[df.groupby('concept')['response_score'].transform(max) == df['response_score']]['response'].values

# #df[df['response_score'] == df['response_score'].min()]['response'].values

# Get rows with the best response for each concept
best_responses = df[df.groupby('concept')['response_score'].transform(max) == df['response_score']]

# Get rows with the worst response for each concept
worst_responses = df[df.groupby('concept')['response_score'].transform(min) == df['response_score']]

# Iterate over unique concepts and print best and worst responses
for concept in df['concept'].unique():
    best_response = best_responses[best_responses['concept'] == concept]['response'].values[0]
    worst_response = worst_responses[worst_responses['concept'] == concept]['response'].values[0]
    
    print(f"Concept: {concept}")
    print(f"Best Response: {best_response}")
    print(f"------")
    print(f"Worst Response: {worst_response}")
    print("------")
    print("*"*50)
# Out:
# Concept: Genetic Mutations
# Best Response: Genetic mutations are changes in the DNA sequence that can occur naturally or be caused by external factors like radiation or chemicals. These mutations can lead to variations in traits and characteristics among individuals within a species. Some mutations may have no effect, while others can cause genetic disorders or provide advantages in survival and reproduction. These variations are essential for the process of evolution, as they contribute to the diversity of life on Earth.
# ------
# Worst Response: Certainly! Genetic mutations are changes in the DNA sequence that can lead to differences in traits or characteristics. These changes can occur naturally or as a result of external factors, and they can have various effects, ranging from no impact to causing genetic disorders. Overall, genetic mutations are a fundamental part of evolution and the diversity of life.
# ------
# **************************************************
# Concept: Overfitting in Machine Learning
# Best Response: Overfitting in machine learning occurs when a model learns to perform well on the training data but does not generalize well to new, unseen data. This happens when the model learns the specific patterns and noise in the training data, rather than the underlying relationships that would allow it to make accurate predictions on new data.
#
# Imagine a scenario where a model is trained to recognize pictures of cats. If the model memorizes the exact features of the cats in the training set, including any anomalies or imperfections, it
# ------
# Worst Response: Of course! Overfitting in machine learning occurs when a model learns the details and noise in the training data to the extent that it negatively impacts its ability to generalize to new, unseen data. Essentially, the model becomes too tailored to the training data and performs poorly when exposed to new data. This can happen when the model is too complex or when the training data is limited. To combat overfitting, techniques such as cross-validation, regularization, and using more data can be employed to help the
# ------
# **************************************************
# /var/folders/5l/y8s3fc655417629rqwgxkhx80000gn/T/ipykernel_68394/1005404446.py:10: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   best_responses = df[df.groupby('concept')['response_score'].transform(max) == df['response_score']]
# /var/folders/5l/y8s3fc655417629rqwgxkhx80000gn/T/ipykernel_68394/1005404446.py:13: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   worst_responses = df[df.groupby('concept')['response_score'].transform(min) == df['response_score']]

# %% [markdown]
# Usually, you would have to tune even the prompt that is being used to create the scores for the responses, to make sure you have the best possible results, but for this particular case let's just analyse overall how well we did with these baseline preliminary results.
